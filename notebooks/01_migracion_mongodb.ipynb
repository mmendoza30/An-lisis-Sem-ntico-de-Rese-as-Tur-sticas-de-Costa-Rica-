# %%
#Instalacion para utilizar MongoDB
 #pip install --upgrade pymongo

# %%
import pandas as pd
df = pd.read_csv('../data/processed/resenas_pos_tagged.csv', sep=',', nrows=7)
print(df.columns.tolist())
print(df.head(3))
# Out:
# ['reseña', 'calificación', 'tipo_lugar', 'fuente', 'nombre', 'fecha', 'grupo_de_viaje', 'tokens_spacy', 'tokens_nltk']
#                                               reseña  calificación tipo_lugar  \
# 0  fue una pésima experiencia llegamos solo por u...             1      hotel
# 1  todo muy bonito realmente me quedo sin palabra...             5      hotel
# 2  una experiencia relajante e imperdible en cost...             5      hotel
#
#                                               fuente  \
# 0  https://search.google.com/local/reviews?placei...
# 1  https://search.google.com/local/reviews?placei...
# 2  https://search.google.com/local/reviews?placei...
#
#                                  nombre       fecha grupo_de_viaje  \
# 0  baldi hot springs hotel resort & spa  05/23/2026            NaN
# 1  baldi hot springs hotel resort & spa  05/17/2026            NaN
# 2  baldi hot springs hotel resort & spa  05/16/2026        familia
#
# ...
